# %%
from ydata_profiling import ProfileReport
import numpy as np
import pandas as pd

# read ../data_objects/merged_commits.txt as jsons
df = pd.read_json('../data_objects/merged_commits.csv', lines=True)  

df["author_date"] = pd.to_datetime(df["author_date"])

df


# profile = ProfileReport(df, title="Profiling Report")
# profile.to_file("o.html")
# Out:
# C:\Users\mikol\AppData\Local\Temp\ipykernel_31384\3489076633.py:8: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df["author_date"] = pd.to_datetime(df["author_date"])
#                                            hash  \
# 0      8f35cc4768393b25468416829e980d7550619fb1
# 1      6f9e2ae3907632e2f7dbbabe8da403edd6dfa120
# 2      43a17862477d0b2b7fb825ffd2a00ac193d2f771
# 3      ef99de7936d45c4199fa51b5654130dafefabe68
# 4      4d275980f12682fd0004950f2c5a885842206d4b
# ...                                         ...
# 34801  42ab601b80e55a8f8e1c1b2849b144989c934eaa
# 34802  e84e16c11b15e01b4ab5a15b21b36d9317316098
# 34803  cdfa26f3c91a7d90200446204da27c49b4dbd7eb
# 34804  ebff39ff2787a12e6e775dab2c6d66f4cae0fdc1
# 34805  04bde9b1e6958d441695f130640fcb0af43e4b84
#
#                                                      msg         author_name  \
# 0                                             Hello Code         Erich Gamma
# 1      Add reference to DefinitelyTyped, updated the ...          Chris Dias
# 2                                  jsdoc fot vscode.d.ts     Johannes Rieken
# 3                         Add source.regexp.python rules  Martin Aeschlimann
# 4                                       add OSS icon set     Benjamin Pasero
# ...                                                  ...                 ...
# 34801                                         fix #50726     Johannes Rieken
# 34802  grid: resize views when branch is demoted\n\nf...         Joao Moreno
# 34803                                         fix #50734     Johannes Rieken
# 34804           remove preview rant from search.location              isidor
# 34805  splitview: dont propagate white-sapce property...         Joao Moreno
#
#                                              author_date  merge  deletions  \
# 0      0        2015-11-13 14:39:38+01:00\n1        2...  False          0
# 1      0        2015-11-13 14:39:38+01:00\n1        2...  False         87
# 2      0        2015-11-13 14:39:38+01:00\n1        2...  False        100
# 3      0        2015-11-13 14:39:38+01:00\n1        2...  False          0
# 4      0        2015-11-13 14:39:38+01:00\n1        2...  False          3
# ...                                                  ...    ...        ...
# 34801  0        2015-11-13 14:39:38+01:00\n1        2...  False          3
# 34802  0        2015-11-13 14:39:38+01:00\n1        2...  False          5
# 34803  0        2015-11-13 14:39:38+01:00\n1        2...  False          0
# 34804  0        2015-11-13 14:39:38+01:00\n1        2...  False          1
# 34805  0        2015-11-13 14:39:38+01:00\n1        2...  False          0
#
#        insertions   lines  files  dmm_unit_size  dmm_unit_complexity  \
# 0          704173  704173   1897       0.463346             0.687042
# 1             247     334      5            NaN                  NaN
# 2             220     320      1            NaN                  NaN
# 3             302     302      2            NaN                  NaN
# 4               3       6      8            NaN                  NaN
# ...           ...     ...    ...            ...                  ...
# 34801           5       8      1            NaN                  NaN
# 34802          29      34      2       0.050000             1.000000
# 34803           1       1      1            NaN                  NaN
# 34804           1       2      1            NaN                  NaN
# 34805           1       1      1            NaN                  NaN
#
#        dmm_unit_interfacing  is_bug
# 0                  0.875693    True
# 1                       NaN    True
# 2                       NaN    True
# 3                       NaN    True
# 4                       NaN    True
# ...                     ...     ...
# 34801                   NaN   False
# 34802              1.000000   False
# 34803                   NaN   False
# 34804                   NaN   False
# 34805                   NaN   False
#
# [34806 rows x 13 columns]
